# %%
# %pip install torch
# Out:
# ...
#      ---------------------------------------- 0.0/192.3 MB ? eta -:--:--
#      -------------------------------------- 0.0/192.3 MB 660.6 kB/s eta 0:04:52
#      -------------------------------------- 0.1/192.3 MB 787.7 kB/s eta 0:04:05
#      ---------------------------------------- 0.2/192.3 MB 1.1 MB/s eta 0:02:48
#      ---------------------------------------- 0.3/192.3 MB 1.6 MB/s eta 0:02:00
#      ---------------------------------------- 0.5/192.3 MB 2.4 MB/s eta 0:01:19
#      ---------------------------------------- 0.8/192.3 MB 2.9 MB/s eta 0:01:07
#      ---------------------------------------- 1.1/192.3 MB 3.6 MB/s eta 0:00:53
#      ---------------------------------------- 1.8/192.3 MB 5.2 MB/s eta 0:00:37
#       --------------------------------------- 2.5/192.3 MB 6.4 MB/s eta 0:00:30
#       --------------------------------------- 2.9/192.3 MB 6.6 MB/s eta 0:00:29
#       --------------------------------------- 3.1/192.3 MB 6.4 MB/s eta 0:00:30
# ...

# %%
import torch
import numpy as np
